# %% [markdown]
# <a href="https://colab.research.google.com/github/SushanthKumble/SPECIAL-REPO/blob/main/tfidf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install emoji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.5/397.5 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import string
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import emoji

# Download NLTK resources (if not already downloaded)
import nltk
nltk.download('punkt')

# Load your CSV file into a pandas DataFrame
csv_file_path = '/content/drive/MyDrive/lab programs/smiling_face_with_heart-eyes.csv'  # Replace with the path to your CSV file
df = pd.read_csv(csv_file_path)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df
# Out:
#                                                     Text
# 0      The Daughter &amp; Son 👫🐇😍 https://t.co/X6rnSP...
# 1      @GoodPieceOfSass That's so cool!! 😍 If you eve...
# 2      @dctwit9491 Hi, my Sean 😍🥰. l've missed you, m...
# 3      jungkooooook 😍💖🥰🥹💋🌼🌈✨🍓🥂 (i was gonna 🔪 about 🛴...
# 4                  @characterbaby The face is FACING 😩😍😍
# ...                                                  ...
# 19995                  @zeldablythee This hair on you 😍😍
# 19996  Going for a walk together at sunset\nBrunch da...
# 19997  passanger nd Train movements. With the Economi...
# 19998  @SaltyGoat17 She is going to lead America back...
# 19999  @MadeleineAriel Shoes is sold out no way yall ...
#
# [20000 rows x 1 columns]

# %%
# Define a function for text preprocessing
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()


    text = emoji.demojize(text)

    # Remove punctuation
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')

    # Tokenize text
    tokens = word_tokenize(text)

    # Remove stop words
    tokens = [token for token in tokens if token not in ENGLISH_STOP_WORDS]

    # Stemming (using Porter stemmer)
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]

    # Join tokens back into text
    processed_text = ' '.join(tokens)

    return processed_text

# Apply text preprocessing to the 'text' column
df['processed_text'] = df['Text'].apply(preprocess_text)

# Initialize the TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()  # Adjust parameters as needed

# Fit and transform the processed text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['processed_text'])

# Convert the TF-IDF matrix to a DataFrame

# Display the TF-IDF DataFrame
print(tfidf_matrix)
# Out:
#   (0, 20746)	0.5617026819529796
#   (0, 44821)	0.5617026819529796
#   (0, 38801)	0.39165562468670656
#   (0, 2269)	0.26326071610839336
#   (0, 8745)	0.3824655032535898
#   (1, 12886)	0.4649119549635671
#   (1, 23836)	0.3537040291463089
#   (1, 21508)	0.3100444850126557
#   (1, 35834)	0.28770484363224863
#   (1, 42384)	0.33458673146707135
#   (1, 36720)	0.09023832904280044
#   (1, 7750)	0.27886429503770355
#   (1, 41001)	0.2566106317833029
#   (1, 14057)	0.4649119549635671
#   (2, 17368)	0.41128358311767116
#   (2, 44991)	0.2450389483624614
#   (2, 4095)	0.14780509133933412
#   (2, 16003)	0.20672539748618207
#   (2, 13085)	0.21711836494716452
#   (2, 27676)	0.23093248379410228
#   (2, 26027)	0.41128358311767116
#   (2, 37541)	0.23901567744877528
#   (2, 35416)	0.3670305054061685
#   (2, 15652)	0.27495734057084426
#   (2, 8872)	0.41128358311767116
#   :	:
#   (19997, 39305)	0.2717018892892312
#   (19997, 10417)	0.2717018892892312
#   (19997, 28223)	0.2482226252161406
# ...

# %%
df
# Out:
#                                                     Text  \
# 0      The Daughter &amp; Son 👫🐇😍 https://t.co/X6rnSP...
# 1      @GoodPieceOfSass That's so cool!! 😍 If you eve...
# 2      @dctwit9491 Hi, my Sean 😍🥰. l've missed you, m...
# 3      jungkooooook 😍💖🥰🥹💋🌼🌈✨🍓🥂 (i was gonna 🔪 about 🛴...
# 4                  @characterbaby The face is FACING 😩😍😍
# ...                                                  ...
# 19995                  @zeldablythee This hair on you 😍😍
# 19996  Going for a walk together at sunset\nBrunch da...
# 19997  passanger nd Train movements. With the Economi...
# 19998  @SaltyGoat17 She is going to lead America back...
# 19999  @MadeleineAriel Shoes is sold out no way yall ...
#
#                                           processed_text
# 0      daughter amp son womanandmanholdinghandsrabbit...
# 1      goodpieceofsass that cool smilingfacewithheart...
# 2      dctwit9491 hi sean smilingfacewithhearteyessmi...
# ...

# %%
# The output you provided is the sparse matrix representation of the TF-IDF (Term Frequency-Inverse Document Frequency) matrix generated by the TfidfVectorizer. Each row in the matrix corresponds to a document (or text sample), and each column corresponds to a unique feature (word or term).

# Let me break down the output:

# The entries (i, j) represent the TF-IDF weight for term (feature) j in document i.
# The values are non-zero only for the terms that appear in the corresponding document.
# The values represent the importance of each term within each document based on TF-IDF weighting.

# %%
dense_tfidf_matrix = tfidf_matrix.toarray()

# %%
import numpy as np

# Assuming your dense array is stored in the variable 'dense_tfidf_matrix'
# Replace with the actual variable name if it's different
print(np.sum(dense_tfidf_matrix != 0))  # Count the non-zero elements
print(dense_tfidf_matrix.shape)  # Print the shape of the matrix
# Out:
# 158262
# (20000, 47002)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
