# %% [markdown]
# <a href="https://colab.research.google.com/github/SushanthKumble/SPECIAL-REPO/blob/main/program3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install nltk

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df = pd.read_csv('/content/drive/MyDrive/lab programs/smiling_face_with_heart-eyes.csv')

# %%
df['Text_Tokenized'] = df['Text'].apply(word_tokenize)

# %%
df
# Out:
#                                                     Text  \
# 0      The Daughter &amp; Son 👫🐇😍 https://t.co/X6rnSP...
# 1      @GoodPieceOfSass That's so cool!! 😍 If you eve...
# 2      @dctwit9491 Hi, my Sean 😍🥰. l've missed you, m...
# 3      jungkooooook 😍💖🥰🥹💋🌼🌈✨🍓🥂 (i was gonna 🔪 about 🛴...
# 4                  @characterbaby The face is FACING 😩😍😍
# ...                                                  ...
# 19995                  @zeldablythee This hair on you 😍😍
# 19996  Going for a walk together at sunset\nBrunch da...
# 19997  passanger nd Train movements. With the Economi...
# 19998  @SaltyGoat17 She is going to lead America back...
# 19999  @MadeleineAriel Shoes is sold out no way yall ...
#
#                                           Text_Tokenized
# 0      [The, Daughter, &, amp, ;, Son, 👫🐇😍, https, :,...
# 1      [@, GoodPieceOfSass, That, 's, so, cool, !, !,...
# 2      [@, dctwit9491, Hi, ,, my, Sean, 😍🥰, ., l, 've...
# ...

# %%
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text)
    no_stopwords_text = [w for w in words if w.lower() not in stop_words]
    return ' '.join(no_stopwords_text)

# %%
df['stopwordsremoved'] = df['Text'].apply(remove_stopwords)

# %%
df
# Out:
#                                                     Text  \
# 0      The Daughter &amp; Son 👫🐇😍 https://t.co/X6rnSP...
# 1      @GoodPieceOfSass That's so cool!! 😍 If you eve...
# 2      @dctwit9491 Hi, my Sean 😍🥰. l've missed you, m...
# 3      jungkooooook 😍💖🥰🥹💋🌼🌈✨🍓🥂 (i was gonna 🔪 about 🛴...
# 4                  @characterbaby The face is FACING 😩😍😍
# ...                                                  ...
# 19995                  @zeldablythee This hair on you 😍😍
# 19996  Going for a walk together at sunset\nBrunch da...
# 19997  passanger nd Train movements. With the Economi...
# 19998  @SaltyGoat17 She is going to lead America back...
# 19999  @MadeleineAriel Shoes is sold out no way yall ...
#
#                                           Text_Tokenized  \
# 0      [The, Daughter, &, amp, ;, Son, 👫🐇😍, https, :,...
# 1      [@, GoodPieceOfSass, That, 's, so, cool, !, !,...
# 2      [@, dctwit9491, Hi, ,, my, Sean, 😍🥰, ., l, 've...
# ...
